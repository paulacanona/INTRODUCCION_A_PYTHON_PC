# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # DATOS

# %%
df = pd.read_excel("C:/Users/Paula/OneDrive/Escritorio/PMYS/INTRODUCCION A PYTHON/INTRODUCCION_A_PYTHON_PC/Proyecto_MYS/Dateframe_aireBog.xlsx")
print(df)
# Out:
#                  DateTime  PM10_(µg-m3)  CO_(ppm)  OZONO_(ppm)  NO_(ppm)  \
# 0     2019-04-01 00:00:00          42.3       1.8          4.9      41.5
# 1     2019-04-01 00:00:00          55.9       1.4         12.6      26.0
# 2     2019-04-01 00:00:00          40.8       1.4          7.2      19.7
# 3     2019-04-02 00:00:00          28.3       1.5          1.0      29.8
# 4     2019-04-02 00:00:00          41.6       1.1         11.2      17.4
# ...                   ...           ...       ...          ...       ...
# 2284           30-05-2022          15.3       0.3         13.4       6.7
# 2285           30-05-2022          16.9       0.5          5.4      13.3
# 2286           31-05-2022          29.0       0.2          1.1      80.7
# 2287           31-05-2022          24.3       0.3         22.3       7.7
# 2288           31-05-2022          25.9       NaN         11.5      12.3
#
#       NO2_(ppm)  NOX_(ppm)  SO2_(ppm)  Vel_Viento_(m-s)  Dir_Viento_(grados)  \
# ...

# %% [markdown]
# # TIPO DE DATOS

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
print(df['DateTime'].dtype)
df['Localidad'] = df['Localidad'].astype(str)
print(df['Localidad'].dtype)
# Out:
# datetime64[ns]
# object

# %%
df.shape
df.info() #inspeccion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2289 entries, 0 to 2288
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DateTime              2289 non-null   datetime64[ns]
#  1   PM10_(µg-m3)          2096 non-null   float64
#  2   CO_(ppm)              1656 non-null   float64
#  3   OZONO_(ppm)           2245 non-null   float64
#  4   NO_(ppm)              2201 non-null   float64
#  5   NO2_(ppm)             2203 non-null   float64
#  6   NOX_(ppm)             2205 non-null   float64
#  7   SO2_(ppm)             1112 non-null   float64
#  8   Vel_Viento_(m-s)      2219 non-null   float64
#  9   Dir_Viento_(grados)   2228 non-null   float64
#  10  Temperatura_(C)       2286 non-null   float64
#  11  Precipitacion_(mm)    2103 non-null   float64
#  12  PM10_Flow_(L-m)       621 non-null    float64
#  13  PM2.5_(µg-m3)         2026 non-null   float64
# ...

# %% [markdown]
# # GENERALIDADES DEL LOS DATOS

# %%
df.describe(include='all')
# Out:
#                              DateTime  PM10_(µg-m3)     CO_(ppm)  OZONO_(ppm)  \
# count                            2289   2096.000000  1656.000000  2245.000000
# unique                            NaN           NaN          NaN          NaN
# top                               NaN           NaN          NaN          NaN
# freq                              NaN           NaN          NaN          NaN
# mean    2020-10-23 10:37:54.180865024     21.241698     1.210628    11.558886
# min               2019-04-01 00:00:00      0.400000     0.000000     0.400000
# 25%               2020-04-03 00:00:00     11.700000     0.300000     3.900000
# 50%               2020-05-28 00:00:00     19.300000     0.500000     9.300000
# 75%               2021-05-29 00:00:00     28.600000     0.900000    16.400000
# max               2022-05-31 00:00:00     89.800000    24.600000    81.800000
# std                               NaN     14.143894     2.440672     9.917456
#
# ...
