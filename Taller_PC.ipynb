# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("C:/Users/Paula/OneDrive/Escritorio/PMYS/INTRODUCCION A PYTHON/INTRODUCCION_A_PYTHON_PC/clasificacion.txt",sep="\t")
df
# Out:
#      ID Caso  Clase_Vino  Alcohol  Acido_Malico  Cenizas  Alcalinidad_Cenizas  \
# 0          1           1    14.23          1.71     2.43                 15.6
# 1          2           1    13.20          1.78     2.14                 11.2
# 2          3           1    13.16          2.36     2.67                 18.6
# 3          4           1    14.37          1.95     2.50                 16.8
# 4          5           1    13.24           NaN     2.87                 21.0
# ..       ...         ...      ...           ...      ...                  ...
# 174      175           3    13.40          3.91     2.48                 23.0
# 175      176           3    13.27          4.28     2.26                 20.0
# 176      177           3    13.17          2.59     2.37                 20.0
# 177      178           3    14.13          4.10     2.74                 24.5
# 178      179           3    14.13          4.10     2.74                 24.5
#
# ...

# %%
df.shape
df.info() #inspeccion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ID Caso                            179 non-null    int64
#  1   Clase_Vino                         179 non-null    int64
#  2   Alcohol                            179 non-null    float64
#  3   Acido_Malico                       176 non-null    float64
#  4   Cenizas                            176 non-null    float64
#  5   Alcalinidad_Cenizas                179 non-null    float64
#  6   Magnesio                           178 non-null    float64
#  7   Fenoles_Totales                    178 non-null    float64
#  8   Flavanoides                        175 non-null    float64
#  9   Fenoles_No_Flavanoides             179 non-null    float64
#  10  Protoantocianinas                  179 non-null    float64
# ...

# %%
print('-------------------------------------------------') # estadisticas descriptivas
print('CÁLCULO DE ESTADÍSTICAS PARA LA VARIABLE CENIZAS')
print(f'El máximo de la variable cenizas es igual a {df.Cenizas.max()}')
print(f'El mínimo de la variable cenizas es igual a {df.Cenizas.min()}')
print(f'La media de la variable cenizas es igual a {round(df.Cenizas.mean(),2)}')
print(f'La desviación estandar de la variable cenizas es igual a {round(df.Cenizas.std(),2)}')
print(f'La varianza de la variable cenizas es igual a {round(df.Cenizas.var(),2)}')
# Out:
# -------------------------------------------------
# CÁLCULO DE ESTADÍSTICAS PARA LA VARIABLE CENIZAS
# El máximo de la variable cenizas es igual a 3.23
# El mínimo de la variable cenizas es igual a 1.36
# La media de la variable cenizas es igual a 2.36
# La desviación estandar de la variable cenizas es igual a 0.27
# La varianza de la variable cenizas es igual a 0.07

# %%
print('-------------------------------------------------')
print('ESTADÍSTICAS RESUMIDAS')
df.describe(include='all')
# Out:
# -------------------------------------------------
# ESTADÍSTICAS RESUMIDAS
#           ID Caso  Clase_Vino     Alcohol  Acido_Malico     Cenizas  \
# count  179.000000  179.000000  179.000000    176.000000  176.000000
# mean    90.000000    1.944134   13.006927      2.321534    2.364602
# std     51.816986    0.776919    0.813932      1.099304    0.273399
# min      1.000000    1.000000   11.030000      0.740000    1.360000
# 25%     45.500000    1.000000   12.365000      1.597500    2.210000
# 50%     90.000000    2.000000   13.050000      1.845000    2.360000
# 75%    134.500000    3.000000   13.685000      3.105000    2.552500
# max    179.000000    3.000000   14.830000      5.650000    3.230000
#
#        Alcalinidad_Cenizas    Magnesio  Fenoles_Totales  Flavanoides  \
# count           179.000000  178.000000       178.000000   175.000000
# mean             19.522905   99.629213         2.289663     2.001943
# std               3.351116   14.232438         0.623723     1.000411
# ...

# %%
df.corr(method="pearson")["Magnesio"] #correlaciones
df.loc[:,"Alcohol":"Prolina"].corr()
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
correlacion=df.corr(method='pearson')
import seaborn as sns
print(correlacion)
plt.figure(figsize=(15,10))
sns.heatmap(correlacion,xticklabels=correlacion.columns,yticklabels=correlacion.
columns,cmap='coolwarm',annot=True)
# Out:
#                                     ID Caso  Clase_Vino   Alcohol  \
# ID Caso                            1.000000    0.938479 -0.344478
# Clase_Vino                         0.938479    1.000000 -0.314150
# Alcohol                           -0.344478   -0.314150  1.000000
# Acido_Malico                       0.502890    0.457438  0.107723
# Cenizas                           -0.004557   -0.036403  0.242724
# Alcalinidad_Cenizas                0.570152    0.523334 -0.295056
# Magnesio                          -0.229713   -0.203807  0.264183
# Fenoles_Totales                   -0.651300   -0.721336  0.299173
# Flavanoides                       -0.756077   -0.845490  0.208733
# Fenoles_No_Flavanoides             0.490701    0.495227 -0.141707
# Protoantocianinas                 -0.407148   -0.499493  0.132623
# Intensidad_Color                   0.270120    0.278573  0.552346
# Matiz                             -0.667057   -0.621756 -0.082642
# ...

# %%
correlacion=df.corr(method='pearson') #medidad agrupadas
sns.heatmap(df.corr()[["Alcohol"]],vmin=-1,vmax=1,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.groupby(["Clase_Vino"])["Alcalinidad_Cenizas"].agg(["count","min","mean","max"])
# Out:
#             count   min       mean   max
# Clase_Vino
# 1              59  11.2  17.037288  25.0
# 2              71  10.6  20.238028  30.0
# 3              49  17.5  21.479592  27.0

# %%
df.groupby("Clase_Vino")[["Alcalinidad_Cenizas","Cenizas"]].agg(["count","min","mean","max","std"])
# Out:
#            Alcalinidad_Cenizas                                  Cenizas        \
#                          count   min       mean   max       std   count   min
# Clase_Vino
# 1                           59  11.2  17.037288  25.0  2.546322      57  2.04
# 2                           71  10.6  20.238028  30.0  3.349770      70  1.36
# 3                           49  17.5  21.479592  27.0  2.277515      49  2.10
#
#
#                 mean   max       std
# Clase_Vino
# 1           2.455965  3.22  0.228800
# 2           2.235143  3.23  0.307018
# 3           2.443265  2.86  0.187810

# %%
df.loc[:,"Clase_Vino":"Prolina"].groupby("Clase_Vino").mean()
# Out:
#               Alcohol  Acido_Malico   Cenizas  Alcalinidad_Cenizas  \
# Clase_Vino
# 1           13.744746      2.000690  2.455965            17.037288
# 2           12.278732      1.877429  2.235143            20.238028
# 3           13.173673      3.356875  2.443265            21.479592
#
#               Magnesio  Fenoles_Totales  Flavanoides  Fenoles_No_Flavanoides  \
# Clase_Vino
# 1           106.172414         2.840169     2.972500                0.290000
# 2            94.549296         2.248000     2.080143                0.363662
# 3            99.244898         1.686327     0.781020                0.449796
#
#             Protoantocianinas  Intensidad_Color     Matiz  \
# Clase_Vino
# 1                    1.899322          5.528305  1.062034
# 2                    1.630282          3.086620  1.056282
# 3                    1.157551          7.492083  0.681224
#
#             OD280_OD315_de_los_vinos_diluidos      Prolina
# Clase_Vino
# ...

# %%
df.loc[:,"Clase_Vino":"Prolina"].groupby("Clase_Vino").corr()
# Out:
#                                                Alcohol  Acido_Malico  \
# Clase_Vino
# 1          Alcohol                            1.000000     -0.024810
#            Acido_Malico                      -0.024810      1.000000
#            Cenizas                           -0.137713     -0.009678
#            Alcalinidad_Cenizas               -0.318367      0.038117
#            Magnesio                           0.167292      0.071272
#            Fenoles_Totales                    0.420687     -0.082288
#            Flavanoides                        0.407812     -0.189791
#            Fenoles_No_Flavanoides             0.015659     -0.113165
#            Protoantocianinas                  0.307571     -0.078472
#            Intensidad_Color                   0.408291     -0.246783
#            Matiz                              0.080020     -0.419936
#            OD280_OD315_de_los_vinos_diluidos  0.069818      0.184462
# ...

# %% [markdown]
# GRAFICOS

# %%
plt.figure(figsize=(20,15)) #Histograma
plt.hist(df["Alcohol"],bins=20)
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title(" Histograma")
plt.show()

# %%
df["Alcalinidad_Cenizas"].plot(kind="box") #Boxplot
plt.xlabel("")
plt.ylabel("Porcentajes")
plt.title(" Boxplot")
plt.show()

# %%
df.loc[:,"Alcohol":"Magnesio"].plot.box(figsize=(20,10))
plt.xlabel("")
plt.ylabel("Porcentajes")
plt.title(" Boxplot")
plt.show()

# %%
plt.scatter(df["Alcohol"],df["Matiz"]) #Dispersion
plt.show()

# %%
g=sns.PairGrid(df,hue="Clase_Vino")
g.map_lower(plt.scatter,alpha=0.6)
g.map_diag(plt.hist,alpha=0.7)

# %%
plt.figure(figsize=(20,15)) #Barras
plt.subplot(231)
df.loc[:,"Alcohol":"Matiz"].mean().plot(kind="bar")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title("Gráfica 1")
# Out:
# Text(0.5, 1.0, 'Gráfica 1')

# %%
df.groupby("Clase_Vino")["Clase_Vino"].count().plot(kind="pie") 
df.groupby("Clase_Vino")["Clase_Vino"].count() # De pie
# Out:
# Clase_Vino
# 1    59
# 2    71
# 3    49
# Name: Clase_Vino, dtype: int64

# %%
df2=df #tratamiento
nulos = df2.isnull().sum()
print(nulos)
df2=df2.fillna(0)
f2=df2.fillna(df2.mean())
df2=df2.interpolate()
df2['Acido_Malico']=df2['Acido_Malico'].fillna('missing')
df2=df2.fillna(df2.mean()['Acido_Malico':'Cenizas'])
# Out:
# ID Caso                              0
# Clase_Vino                           0
# Alcohol                              0
# Acido_Malico                         3
# Cenizas                              3
# Alcalinidad_Cenizas                  0
# Magnesio                             1
# Fenoles_Totales                      1
# Flavanoides                          4
# Fenoles_No_Flavanoides               0
# Protoantocianinas                    0
# Intensidad_Color                     0
# Matiz                                0
# OD280_OD315_de_los_vinos_diluidos    0
# Prolina                              0
# dtype: int64

# %%
df=df[df['Intensidad_Color']<10] #Filtrado
df=df[(df['Intensidad_Color']<10)&(df['Matiz']<1.5)]
